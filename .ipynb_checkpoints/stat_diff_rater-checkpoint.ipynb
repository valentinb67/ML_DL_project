# %%
pip install ace_tools_open
# Out:
# Collecting ace_tools_open
#   Downloading ace_tools_open-0.1.0-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: IPython in c:\users\busch\anaconda3\lib\site-packages (from ace_tools_open) (8.2.0)
# Collecting itables
#   Downloading itables-2.2.4-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: pandas in c:\users\busch\anaconda3\lib\site-packages (from ace_tools_open) (1.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (3.0.20)
# Requirement already satisfied: colorama in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (0.4.4)
# Requirement already satisfied: traitlets>=5 in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (61.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (2.18.0)
# Requirement already satisfied: pickleshare in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (0.2.0)
# Requirement already satisfied: backcall in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (0.2.0)
# Requirement already satisfied: decorator in c:\users\busch\anaconda3\lib\site-packages (from IPython->ace_tools_open) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\busch\anaconda3\lib\site-packages (from jedi>=0.16->IPython->ace_tools_open) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\busch\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->ace_tools_open) (0.2.5)
# Requirement already satisfied: numpy in c:\users\busch\anaconda3\lib\site-packages (from itables->ace_tools_open) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\busch\anaconda3\lib\site-packages (from pandas->ace_tools_open) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\busch\anaconda3\lib\site-packages (from pandas->ace_tools_open) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\busch\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->ace_tools_open) (1.16.0)
# Requirement already satisfied: executing in c:\users\busch\anaconda3\lib\site-packages (from stack-data->IPython->ace_tools_open) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\busch\anaconda3\lib\site-packages (from stack-data->IPython->ace_tools_open) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\busch\anaconda3\lib\site-packages (from stack-data->IPython->ace_tools_open) (0.2.2)
# Installing collected packages: itables, ace-tools-open
# Successfully installed ace-tools-open-0.1.0 itables-2.2.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\busch\anaconda3\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor

# %%
data = pd.read_csv('data_football_ratings.csv')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import numpy as np
import ace_tools_open as tools

# Préparation des données pour le clustering
# Moyenne des notes par équipe et par noteur
pivot_data = data.pivot_table(values='original_rating', index='team', columns='rater', aggfunc=np.mean)

# Normalisation des données
scaler = StandardScaler()
scaled_data = scaler.fit_transform(pivot_data.fillna(0))  # Remplacer les valeurs manquantes par 0

# Application de l'algorithme KMeans pour identifier les groupes
kmeans = KMeans(n_clusters=4, random_state=42)  # Choix de 4 clusters pour commencer
clusters = kmeans.fit_predict(scaled_data)

# Ajout des clusters aux données
pivot_data['Cluster'] = clusters

# Affichage des résultats
tools.display_dataframe_to_user("Groupes par Similarités", pivot_data)
# Out:
# Groupes par Similarités
# <table id="itables_38bdc9ed_fb37_4636_a491_73a02e374714" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th>rater</th>
#       <th>Bild</th>
#       <th>Kicker</th>
#       <th>SkySports</th>
#       <th>SofaScore</th>
#       <th>TheGuardian</th>
#       <th>WhoScored</th>
#       <th>Cluster</th>
#     </tr>
#     <tr>
#       <th>team</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_38bdc9ed_fb37_4636_a491_73a02e374714:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["Albania", NaN, 3.544118, NaN, 6.765625, 6.0, 6.560238, 3], ["Argentina", NaN, 3.947917, 6.0, 6.754545, NaN, 6.577091, 0], ["Arsenal", NaN, NaN, 6.255578, NaN, NaN, 6.934047, 2], ["Augsburg", 3.369085, 3.436387, NaN, NaN, NaN, 6.765534, 1], ["Australia", NaN, 3.814286, 6.365854, 6.70303, NaN, 6.468571, 0], ["Austria", NaN, 3.777778, NaN, 6.857576, 5.928571, 6.594524, 3], ["Bayer Leverkusen", 3.522648, 3.265707, NaN, NaN, NaN, 6.847385, 1], ["Bayern Munich", 3.10061, 3.087927, NaN, NaN, NaN, 7.12261, 1], ["Belgium", NaN, 3.219424, 6.449438, 7.189231, 6.0, 7.051049, 3], ["Borussia Dortmund", 3.39781, 3.427224, NaN, NaN, NaN, 6.926884, 1], ["Borussia M.Gladbach", 3.586103, 3.446565, NaN, NaN, NaN, 6.785011, 1], ["Bournemouth", NaN, NaN, 6.193833, NaN, NaN, 6.66719, 2], ["Brazil", NaN, 3.338983, 6.369231, 7.174545, NaN, 7.055571, 0], ["Brighton", NaN, NaN, 6.253036, NaN, NaN, 6.692505, 2], ["Burnley", NaN, NaN, 6.415493, NaN, NaN, 6.770618, 2], ["Chelsea", NaN, NaN, 6.238, NaN, NaN, 6.947946, 2], ["Colombia", NaN, 3.401961, 6.272727, 6.856818, NaN, 6.778947, 0], ["Costa Rica", NaN, 3.842857, 6.305556, 6.721212, NaN, 6.520976, 0], ["Croatia", NaN, 3.208696, 6.467532, 7.065455, 6.702703, 6.957836, 3], ["Crystal Palace", NaN, NaN, 6.182628, NaN, NaN, 6.853787, 2], ["Czech Republic", NaN, 3.808824, NaN, 6.696774, 5.642857, 6.501951, 3], ["Denmark", NaN, 3.571429, 6.113208, 6.936364, NaN, 6.792407, 0], ["Egypt", NaN, 4.1, 6.189189, 6.624242, NaN, 6.473333, 0], ["Eintracht Frankfurt", 3.581633, 3.474734, NaN, NaN, NaN, 6.736456, 1], ["England", NaN, 3.46281, 6.808989, 7.086364, NaN, 6.853022, 0], ["Everton", NaN, NaN, 6.029724, NaN, NaN, 6.670542, 2], ["FC Koln", 4.03125,
# Définir les listes de clubs et d'équipes pour chaque catégorie
english_clubs = ['Arsenal', 'Chelsea', 'Liverpool', 'Manchester City', 'Manchester United', 'Tottenham', 'Watford', 'West Bromwich Albion',
                'Huddersfield', 'Leicester', 'Everton', 'Stoke', 'Southampton', 'Swansea','Bournemouth', 'Crystal Palace', 'Brighton', 'Newcastle United', 'West Ham']
german_clubs = ['Bayern Munich', 'Borussia Dortmund', 'RB Leipzig', 'Augsburg', 'Werder Bremen', 'Schalke 04', 'Wolfsburg', 'Bayer Leverkusen', 'Hamburger SV',
               'RasenBallsport Leipzig', 'Hannover 96', 'VfB Stuttgart', 'Mainz 05', 'Hoffenheim', 'Hertha Berlin',	'Borussia M.Gladbach', 'FC Koln',
                'Eintracht Frankfurt', 'Freiburg']
european_national_teams = ['France', 'Germany', 'Italy', 'Spain', 'Portugal', 'Netherlands', 'Belgium', 'England', 'Romania', 'Albania', 'Austria', 'Switzerland']
rest_of_world_national_teams = list(set(data['team'].unique()) - set(english_clubs) - set(german_clubs) - set(european_national_teams))

# Création des colonnes dummies
data['English_Club'] = data['team'].apply(lambda x: 1 if x in english_clubs else 0)
data['German_Club'] = data['team'].apply(lambda x: 1 if x in german_clubs else 0)
data['European_National_Team'] = data['team'].apply(lambda x: 1 if x in european_national_teams else 0)
data['Rest_of_World_National_Team'] = data['team'].apply(lambda x: 1 if x in rest_of_world_national_teams else 0)

# %%
tools.display_dataframe_to_user("Dummies pour les catégories de clubs et d'équipes", data[['team', 'English_Club', 'German_Club', 'European_National_Team', 'Rest_of_World_National_Team']].drop_duplicates())
# Out:
# Dummies pour les catégories de clubs et d'équipes
# <table id="itables_ab6638ef_880f_4128_b61c_c0b051c7bb55" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>team</th>
#       <th>English_Club</th>
#       <th>German_Club</th>
#       <th>European_National_Team</th>
#       <th>Rest_of_World_National_Team</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ab6638ef_880f_4128_b61c_c0b051c7bb55:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[0, "Romania", 0, 0, 1, 0], [3, "France", 0, 0, 1, 0], [72, "Russia", 0, 0, 0, 1], [73, "Slovakia", 0, 0, 0, 1], [77, "Wales", 0, 0, 0, 1], [81, "Switzerland", 0, 0, 1, 0], [88, "Albania", 0, 0, 1, 0], [100, "England", 0, 0, 1, 0], [301, "Croatia", 0, 0, 0, 1], [305, "Turkey", 0, 0, 0, 1], [309, "Poland", 0, 0, 0, 1], [322, "Germany", 0, 0, 1, 0], [326, "Northern Ireland", 0, 0, 0, 1], [344, "Ukraine", 0, 0, 0, 1], [562, "Ireland", 0, 0, 0, 1], [565, "Belgium", 0, 0, 1, 0], [571, "Czech Republic", 0, 0, 0, 1], [581, "Sweden", 0, 0, 0, 1], [594, "Spain", 0, 0, 1, 0], [750, "Italy", 0, 0, 1, 0], [800, "Iceland", 0, 0, 0, 1], [803, "Hungary", 0, 0, 0, 1], [806, "Portugal", 0, 0, 1, 0],

#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
count_by_dummy_correct = data.melt(id_vars=['rater'], value_vars=dummies, var_name='Category', value_name='Is_Present')
count_summary = count_by_dummy_correct[count_by_dummy_correct['Is_Present'] == 1].groupby(['Category', 'rater']).size().unstack(fill_value=0)

# Affichage du tableau
tools.display_dataframe_to_user("Nombre de joueurs notés par chaque journal pour chaque catégorie de dummies (correct)", count_summary)
# Out:
# Nombre de joueurs notés par chaque journal pour chaque catégorie de dummies (correct)
# <table id="itables_40246b77_dfd1_4165_a14d_9e497df81bdc" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th>rater</th>
#       <th>Bild</th>
#       <th>Kicker</th>
#       <th>SkySports</th>
#       <th>SofaScore</th>
#       <th>TheGuardian</th>
#       <th>WhoScored</th>
#     </tr>
#     <tr>
#       <th>Category</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_40246b77_dfd1_4165_a14d_9e497df81bdc:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["English_Club", 0, 0, 9118, 0, 24, 9701], ["European_National_Team", 0, 972, 459, 910, 354, 1141], ["German_Club", 5519, 6970, 0, 0, 0, 8174], ["Rest_of_World_National_Team", 0, 1606, 1557, 1492, 317, 2338]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
# Définition des nationalités des journaux
journal_nationalities = {
    'Bild': 'Germany',
    'Kicker': 'Germany',
    'SkySports': 'UK',
    'SofaScore': 'Croatia',
    'TheGuardian': 'UK',
    'WhoScored': 'UK'
}

# Création des colonnes dummies pour chaque nationalité
for nationality_rater in set(journal_nationalities.values()):
    data[nationality_rater] = data['rater'].apply(lambda x: 1 if journal_nationalities.get(x) == nationality else 0)

# %%
team_nationality_map = data[['team', 'English_Club', 'German_Club', 'European_National_Team', 'Rest_of_World_National_Team']].drop_duplicates()

# Création d'une colonne pour la nationalité de l'équipe
def get_team_nationality(row):
    if row['English_Club'] == 1:
        return 'English Club'
    elif row['German_Club'] == 1:
        return 'German Club'
    elif row['European_National_Team'] == 1:
        return 'European National Team'
    elif row['Rest_of_World_National_Team'] == 1:
        return 'Rest of World National Team'
    else:
        return 'Unknown'

team_nationality_map['Team_Nationality'] = team_nationality_map.apply(get_team_nationality, axis=1)

data = data.merge(team_nationality_map[['team', 'Team_Nationality']], on='team', how='left')

# Attribution de la nationalité des journaux
def get_journal_nationality(rater):
    return journal_nationalities.get(rater, 'Other')

data['Journal_Nationality'] = data['rater'].apply(get_journal_nationality)

# Moyenne des notes par équipe et par nationalité du journal
avg_ratings = data.groupby(['team', 'Team_Nationality', 'Journal_Nationality'])['original_rating'].mean().reset_index()

# %%
# Trier les équipes par la nationalité de l'équipe
avg_ratings_sorted = avg_ratings.sort_values(by='Team_Nationality')

plt.figure(figsize=(15, 8))
sns.barplot(x='team', y='original_rating', hue='Journal_Nationality', data=avg_ratings_sorted)

plt.title('Relation entre la nationalité du journal, la note et la nationalité de l\'équipe')
plt.xlabel('Équipe (classée par nationalité)')
plt.ylabel('Note Moyenne des Joueurs')
plt.xticks(rotation=90)
plt.legend(title='Nationalité du Journal')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\busch\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
